# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("datatraffic.csv")
df2 = pd.read_csv("datatraffic2.csv")

# %%
plt.figure(figsize=(12, 8), dpi = 200)
plt.plot(df1['tempo'],df1['traffic'], color = 'blue',label = 'Slice1')
#plt.plot(df2['tempo'],df2['traffic'], color = 'red',label = 'Slice2')
plt.xlabel('Seconds', fontsize = 15)
plt.ylabel('Traffic in Gbps', fontsize = 15)
plt.legend()
